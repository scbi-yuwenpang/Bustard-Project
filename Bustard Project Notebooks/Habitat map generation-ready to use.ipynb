# %% [markdown]
# # Ready version of generating the annual habitat maps
# - created on 9/11/2026
# - developed and modified from `Habitat mapping Ediction3.ipyynb`
# - all the tuned functions/scripts have been saved in the .py files.
#
# ```Text
#
# The script automatically:
#
# Loads or builds the HY2025 sample table.
# Downloads the sample table to pandas.
# Runs the fixed polygon-grouped five-fold CV.
# Evaluates both:
# Features6_Leaf2_MapMatched
# Balanced_Features6_Leaf2_Sensitivity
# Saves fold, pooled, per-class, confusion-matrix, polygon-majority, and variable-importance tables.
# Trains the 500-tree GEE classifier.
# Saves GEE training and out-of-bag diagnostics.
# Exports the classifier as an Earth Engine asset.
# Creates annual Sentinel-2 habitat maps.
# Exports maps to both Earth Engine Assets and Google Drive.
#
#
#
# A two-scale Earth-observation framework was used to balance spatial detail and temporal continuity. The contemporary Habitat Year 2025 inventory was mapped from Sentinel-2 surface reflectance at a nominal 10 m resolution. Long-term habitat dynamics from Habitat Years 2008–2025 were derived independently from Landsat Collection 2 Level-2 surface reflectance at 30 m using Landsat 5, 7, 8, and 9. The Landsat series was processed using a common spectral-band definition, cloud-screening procedure, ecological-year compositing framework, predictor set, output grid, and classification legend. The Sentinel-2 product was used to characterize contemporary fine-scale habitat patterns and to assess the spatial detail lost at Landsat resolution, but it was not inserted directly into the Landsat temporal sequence.
#
# Detailed contemporary classification
# --------------------------------------
# Sentinel-2 SR Harmonized
# 10 m
# Habitat Year 2025
# Possibly extend to HY2018–HY2025
#
#
# Long-term habitat dynamics
# --------------------------
# Landsat Collection 2 Level-2 SR
# Landsat 5 + 7 + 8 + 9
# 30 m
# Habitat Years 2008–2025
#
#
# Recent-period sensitivity analysis
# ----------------------------------
# NASA HLS L30 + S30
# 30 m
# Recent overlap years only
# Optional
